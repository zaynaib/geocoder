# %%
import pandas as pd
from ast import literal_eval

# %%
df = pd.read_csv('oemc_geocoded_final_batch_missingness.csv', converters={'zipcodes': pd.eval})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/test/lib/python3.10/site-packages/pandas/core/computation/scope.py:202, in Scope.resolve(self, key, is_local)
#     201     assert not is_local and not self.has_resolvers
# --> 202     return self.scope[key]
#     203 except KeyError:
#
# File /usr/lib/python3.10/collections/__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File /usr/lib/python3.10/collections/__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# --> 978     raise KeyError(key)
#
# KeyError: 'nan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['zipcodes'][0]
# Out:
# '[60620]'

# %%
df
# Out:
#         Unnamed: 0  EventNumber            EntryDate EventType  \
# 0                0   2000100015  01/01/2020 00.00.52    DISTME
# 1                1   2000100451  01/01/2020 00.21.18      DIST
# 2                2   2000100656  01/01/2020 00.33.55    DOMBAT
# 3                3   2000100660  01/01/2020 00.34.00    DISTME
# 4                4   2000100902  01/01/2020 00.47.02    CHECWB
# ...            ...          ...                  ...       ...
# 176951      171261   2215817626  06/07/2022 23.14.30       EMS
# 176952      171262   2215817828  06/07/2022 23.34.41    DISTME
# 176953      171263   2215817871  06/07/2022 23.39.06    DISTME
# 176954      171264   2215817931  06/07/2022 23.47.19    DISTME
# 176955      171265   2215818077  06/07/2022 23.59.30    DISTME
#
#                   TypeDescription FinalDisposition                Location  \
# 0       MENTAL HEALTH DISTURBANCE              19B      76XX  S HALSTED ST
# ...

# %%
def stringSetToInt(strZip):
    result = None
    try:
        return int(strZip[1:6])
    except:
        return result

# %%
#read in all of the data
for i in range(30):
    exec(f'batch{i} = pd.read_csv("geocoded_batches/batch{i}.csv")')

# %%
#clean the data only take the first zipcode of each set
for i in range(30):
    exec(f'batch{i}["clean_zipcodes"] = batch{i}["zipcodes"].apply(stringSetToInt)')

# %%
whole_batch = pd.concat([batch0, batch1, batch2, batch3, batch4 ,batch5,batch6,batch7,batch8,batch9,batch10,batch11,batch12,batch13
       ,batch14,batch15,batch16,batch17,batch18,batch19,batch20,batch21,batch22,batch23,batch24
       ,batch25,batch26,batch27,batch28,batch29])

whole_batch
# Out:
#       Unnamed: 0  EventNumber            EntryDate EventType  \
# 0              0   2000100015  01/01/2020 00.00.52    DISTME
# 1              1   2000100451  01/01/2020 00.21.18      DIST
# 2              2   2000100656  01/01/2020 00.33.55    DOMBAT
# 3              3   2000100660  01/01/2020 00.34.00    DISTME
# 4              4   2000100902  01/01/2020 00.47.02    CHECWB
# ...          ...          ...                  ...       ...
# 5703      171261   2215817626  06/07/2022 23.14.30       EMS
# 5704      171262   2215817828  06/07/2022 23.34.41    DISTME
# 5705      171263   2215817871  06/07/2022 23.39.06    DISTME
# 5706      171264   2215817931  06/07/2022 23.47.19    DISTME
# 5707      171265   2215818077  06/07/2022 23.59.30    DISTME
#
#                 TypeDescription FinalDisposition                Location  \
# 0     MENTAL HEALTH DISTURBANCE              19B      76XX  S HALSTED ST
# 1                   DISTURBANCE              4PZ   103XX  S SPAULDING AV
# ...

# %%
whole_batch.iloc[24,14]
# Out:
# "['60611', 60611]"

# %%
whole_batch.iloc[24,14][1:6]
# Out:
# "'6061"

# %%
int(strZip[1:6])

# %%
#how many NA's are in this dataset
whole_batch[whole_batch['clean_zipcodes'].isnull()]
# Out:
#       Unnamed: 0  EventNumber            EntryDate EventType  \
# 3              3   2000100660  01/01/2020 00.34.00    DISTME
# 16            16   2000102204  01/01/2020 01.59.07    THREAS
# 19            19   2000102690  01/01/2020 02.24.45    DISTME
# 24            24   2000103462  01/01/2020 03.04.09    THREAS
# 26            26   2000103846  01/01/2020 03.28.07    DISTME
# ...          ...          ...                  ...       ...
# 5687      171245   2215816273  06/07/2022 21.38.45    SHOTSF
# 5689      171247   2215816336  06/07/2022 21.43.04    SUPPOR
# 5690      171248   2215816614  06/07/2022 22.00.09    PERHLP
# 5699      171257   2215817099  06/07/2022 22.30.09    SHOTSF
# 5700      171258   2215817334  06/07/2022 22.47.50    DOMBAT
#
#                 TypeDescription FinalDisposition  \
# 3     MENTAL HEALTH DISTURBANCE             19PZ
# 16          THREATENING SUICIDE              19P
# 19    MENTAL HEALTH DISTURBANCE            5079Z
# ...

# %%
whole_batch['clean_zipcodes'].value_counts()
# Out:
# 60619.0    8512
# 60649.0    6334
# 60628.0    5811
# 60620.0    5578
# 60617.0    5078
# 60640.0    5062
# 60626.0    4747
# 60624.0    4504
# 60629.0    4022
# 60636.0    4000
# 60644.0    3876
# 60651.0    3437
# 60621.0    3324
# 60609.0    3300
# 60608.0    3189
# 60637.0    3114
# 60623.0    2881
# 60643.0    2714
# 60618.0    2666
# 60657.0    2634
# 60641.0    2611
# 60612.0    2548
# 60610.0    2432
# 60625.0    2353
# 60632.0    2305
# 60616.0    2231
# 60653.0    2212
# 60639.0    2147
# 60647.0    1919
# 60615.0    1880
# 60634.0    1762
# 60660.0    1700
# 60607.0    1652
# 60611.0    1568
# 60659.0    1563
# 60614.0    1473
# 60630.0    1361
# 60622.0    1349
# 60613.0    1306
# 60601.0    1180
# 60605.0    1170
# 60645.0    1116
# 60652.0    1076
# 60638.0     980
# 60642.0     796
# 60654.0     712
# 60602.0     671
# 60656.0     594
# 60827.0     570
# 60707.0     557
# 60655.0     428
# 60646.0     418
# 60661.0     411
# 60631.0     357
# 60604.0     352
# ...

# %% [markdown]
# 1) mental health disturbances,
#
# (2) threatening suicide,
#
# (3) domestic disturbance,
#
# (4) disturbance,
#
# (5) attempt suicide?

# %%
whole_batch['TypeDescription'].value_counts()[0:20]
# Out:
# MENTAL HEALTH DISTURBANCE    57309
# CHECK WELL BEING             21444
# THREATENING SUICIDE          14913
# DOMESTIC DISTURBANCE         12143
# DISTURBANCE                  10463
# EMS                           6209
# ASSAULT IP                    3922
# PERSON WITH A KNIFE           3100
# ATTEMPT SUICIDE               2779
# DOMESTIC BATTERY              2744
# DISTURBANCE - MUSIC/NOISE     2399
# CRIMINAL TRESPASS IP          2314
# SUSPICIOUS PERSON             2283
# BATTERY IP                    2188
# MISSING PERSON                2033
# NO POLICE SERVICE             2012
# PERSON WITH A GUN             1883
# SEX OFFENSE OTHER             1192
# ASSAULT JO                    1057
# BATTERY JO                    1021
# Name: TypeDescription, dtype: int64

# %%
mental_disturbance = whole_batch[whole_batch['TypeDescription'] == 'MENTAL HEALTH DISTURBANCE']
mental_disturbance.head()
# Out:
#     Unnamed: 0  EventNumber            EntryDate EventType  \
# 0            0   2000100015  01/01/2020 00.00.52    DISTME
# 3            3   2000100660  01/01/2020 00.34.00    DISTME
# 8            8   2000100999  01/01/2020 00.52.12    DISTME
# 12          12   2000101523  01/01/2020 01.20.34    DISTME
# 15          15   2000101661  01/01/2020 01.28.59    DISTME
#
#               TypeDescription FinalDisposition                Location  \
# 0   MENTAL HEALTH DISTURBANCE              19B      76XX  S HALSTED ST
# 3   MENTAL HEALTH DISTURBANCE             19PZ  31XX .5 N SPAULDING AV
# 8   MENTAL HEALTH DISTURBANCE            5079Z     50XX  S MICHIGAN AV
# 12  MENTAL HEALTH DISTURBANCE               7I    51XX  N MILWAUKEE AV
# 15  MENTAL HEALTH DISTURBANCE              19P       77XX  S SAWYER AV
#
#    CPDUnitList CFDUnitList  numerical directional  street_name suffix  \
# 0         621R         NaN       7600           S      HALSTED     ST
# ...

# %%
mental_disturbance['clean_zipcodes'].value_counts()
# Out:
# 60628.0    2101
# 60649.0    2056
# 60619.0    1972
# 60620.0    1936
# 60624.0    1754
# 60640.0    1648
# 60617.0    1616
# 60636.0    1553
# 60644.0    1511
# 60626.0    1471
# 60651.0    1343
# 60629.0    1235
# 60621.0    1157
# 60637.0    1136
# 60609.0    1122
# 60608.0    1040
# 60623.0    1017
# 60643.0     957
# 60612.0     949
# 60618.0     913
# 60641.0     902
# 60610.0     863
# 60639.0     767
# 60657.0     763
# 60625.0     742
# 60615.0     720
# 60632.0     695
# 60647.0     676
# 60653.0     671
# 60616.0     668
# 60607.0     601
# 60634.0     598
# 60660.0     544
# 60659.0     528
# 60611.0     498
# 60614.0     484
# 60622.0     445
# 60630.0     423
# 60652.0     421
# 60613.0     405
# 60645.0     404
# 60605.0     374
# 60601.0     366
# 60638.0     326
# 60642.0     289
# 60707.0     228
# 60602.0     225
# 60654.0     223
# 60827.0     202
# 60656.0     146
# 60655.0     145
# 60646.0     140
# 60661.0     136
# 60631.0     103
# 60603.0     100
# ...

# %%
threatening = whole_batch[whole_batch['TypeDescription'] == 'THREATENING SUICIDE']
threatening['clean_zipcodes'].value_counts()
# Out:
# 60640.0    494
# 60619.0    422
# 60626.0    413
# 60649.0    404
# 60624.0    392
# 60620.0    369
# 60608.0    365
# 60628.0    354
# 60641.0    349
# 60609.0    346
# 60629.0    339
# 60618.0    310
# 60657.0    306
# 60623.0    300
# 60617.0    287
# 60636.0    270
# 60632.0    268
# 60644.0    260
# 60639.0    258
# 60651.0    247
# 60616.0    241
# 60610.0    241
# 60611.0    237
# 60621.0    237
# 60612.0    235
# 60607.0    234
# 60637.0    231
# 60625.0    214
# 60647.0    196
# 60660.0    190
# 60634.0    188
# 60613.0    178
# 60622.0    176
# 60643.0    160
# 60630.0    154
# 60615.0    150
# 60614.0    144
# 60659.0    136
# 60653.0    132
# 60605.0    130
# 60638.0    109
# 60645.0    105
# 60601.0    104
# 60642.0     98
# 60652.0     84
# 60654.0     78
# 60656.0     73
# 60661.0     59
# 60631.0     50
# 60633.0     50
# 60827.0     47
# 60604.0     44
# 60602.0     43
# 60707.0     43
# 60646.0     40
# 60655.0     39
# 60603.0     24
# 60606.0     14
# ...

# %%
domestic_disturbance = whole_batch[whole_batch['TypeDescription'] == 'DOMESTIC DISTURBANCE']
domestic_disturbance['clean_zipcodes'].value_counts()
# Out:
# 60619.0    801
# 60649.0    710
# 60628.0    666
# 60620.0    660
# 60617.0    645
# 60629.0    470
# 60624.0    428
# 60651.0    410
# 60636.0    405
# 60644.0    353
# 60637.0    330
# 60609.0    305
# 60621.0    299
# 60643.0    295
# 60623.0    265
# 60647.0    246
# 60653.0    232
# 60626.0    205
# 60608.0    204
# 60632.0    202
# 60641.0    187
# 60639.0    156
# 60618.0    156
# 60612.0    153
# 60634.0    153
# 60615.0    129
# 60640.0    126
# 60659.0    119
# 60616.0    111
# 60625.0     99
# 60630.0     99
# 60652.0     95
# 60645.0     85
# 60827.0     82
# 60638.0     79
# 60660.0     63
# 60657.0     62
# 60622.0     60
# 60610.0     53
# 60707.0     49
# 60613.0     45
# 60656.0     45
# 60655.0     40
# 60614.0     30
# 60631.0     28
# 60633.0     25
# 60642.0     22
# 60607.0     17
# 60611.0     17
# 60646.0     16
# 60605.0     14
# 60661.0      9
# 60601.0      8
# 60654.0      8
# 60602.0      6
# 60603.0      2
# 60604.0      2
# 60606.0      1
# ...

# %%
disturbance = whole_batch[whole_batch['TypeDescription'] == 'DISTURBANCE']
disturbance['clean_zipcodes'].value_counts()
# Out:
# 60619.0    451
# 60649.0    401
# 60640.0    369
# 60626.0    365
# 60617.0    316
# 60628.0    301
# 60657.0    268
# 60620.0    252
# 60636.0    228
# 60608.0    223
# 60629.0    203
# 60621.0    199
# 60653.0    198
# 60610.0    198
# 60643.0    197
# 60601.0    192
# 60611.0    171
# 60618.0    167
# 60624.0    165
# 60616.0    164
# 60612.0    163
# 60625.0    162
# 60614.0    156
# 60609.0    152
# 60607.0    146
# 60651.0    142
# 60637.0    139
# 60605.0    138
# 60644.0    133
# 60615.0    131
# 60632.0    117
# 60602.0    116
# 60659.0    114
# 60654.0    114
# 60630.0    113
# 60641.0    103
# 60613.0    102
# 60639.0     93
# 60660.0     91
# 60647.0     82
# 60623.0     82
# 60642.0     77
# 60622.0     74
# 60604.0     66
# 60603.0     62
# 60634.0     54
# 60645.0     42
# 60652.0     42
# 60656.0     41
# 60661.0     35
# 60638.0     30
# 60606.0     30
# 60633.0     16
# 60827.0     16
# 60646.0     16
# 60655.0     14
# 60631.0     13
# 60707.0     13
# ...

# %%
attempt_suicide = whole_batch[whole_batch['TypeDescription'] == 'ATTEMPT SUICIDE']
attempt_suicide['clean_zipcodes'].value_counts()
# Out:
# 60619.0    105
# 60624.0     97
# 60629.0     85
# 60644.0     76
# 60620.0     76
# 60649.0     75
# 60609.0     70
# 60641.0     69
# 60632.0     69
# 60618.0     69
# 60640.0     67
# 60623.0     67
# 60628.0     62
# 60626.0     62
# 60608.0     55
# 60637.0     55
# 60621.0     54
# 60647.0     52
# 60625.0     51
# 60651.0     51
# 60643.0     50
# 60636.0     50
# 60657.0     49
# 60617.0     47
# 60634.0     45
# 60639.0     43
# 60610.0     42
# 60660.0     41
# 60611.0     39
# 60616.0     37
# 60630.0     36
# 60613.0     33
# 60638.0     33
# 60615.0     31
# 60659.0     31
# 60622.0     30
# 60612.0     30
# 60607.0     29
# 60614.0     29
# 60645.0     22
# 60653.0     21
# 60642.0     20
# 60605.0     19
# 60652.0     17
# 60646.0     16
# 60601.0     15
# 60656.0     15
# 60707.0     14
# 60633.0     12
# 60827.0     12
# 60655.0     11
# 60631.0     10
# 60654.0      9
# 60661.0      8
# 60604.0      4
# 60602.0      4
# 60606.0      2
# 60603.0      2
# ...

# %%
test_batch = pd.read_csv('geocoded_batches/batch_test.csv')

# %%
test_batch.head()
# Out:
#    Unnamed: 0  EventNumber            EntryDate EventType  \
# 0           1   2000100451  01/01/2020 00.21.18      DIST
# 1           2   2000100656  01/01/2020 00.33.55    DOMBAT
# 2           3   2000100660  01/01/2020 00.34.00    DISTME
# 3           4   2000100902  01/01/2020 00.47.02    CHECWB
# 4           5   2000100939  01/01/2020 00.49.17    CHECWB
#
#              TypeDescription FinalDisposition                Location  \
# 0                DISTURBANCE              4PZ   103XX  S SPAULDING AV
# 1           DOMESTIC BATTERY            5079Z       40XX  W SCHOOL ST
# 2  MENTAL HEALTH DISTURBANCE             19PZ  31XX .5 N SPAULDING AV
# 3           CHECK WELL BEING              550  65XX  W IRVING PARK RD
# 4           CHECK WELL BEING              19B     50XX  N SHERIDAN RD
#
#                                      CPDUnitList  CFDUnitList  numerical  \
# 0                                    2211R 2213R          NaN      10300
# ...

# %%
test_batch[['zipcodes']].iloc[0][0]
# Out:
# '[60655]'

# %%
from ast import literal_eval
df = pd.read_csv('oemc_geocoded_final_batch.csv', converters={'zipcodes': literal_eval})

# %%
df.head()
# Out:
#    Unnamed: 0  EventNumber            EntryDate EventType  \
# 0           1   2000100451  01/01/2020 00.21.18      DIST
# 1           2   2000100656  01/01/2020 00.33.55    DOMBAT
# 2           3   2000100660  01/01/2020 00.34.00    DISTME
# 3           4   2000100902  01/01/2020 00.47.02    CHECWB
# 4           5   2000100939  01/01/2020 00.49.17    CHECWB
#
#              TypeDescription FinalDisposition                Location  \
# 0                DISTURBANCE              4PZ   103XX  S SPAULDING AV
# 1           DOMESTIC BATTERY            5079Z       40XX  W SCHOOL ST
# 2  MENTAL HEALTH DISTURBANCE             19PZ  31XX .5 N SPAULDING AV
# 3           CHECK WELL BEING              550  65XX  W IRVING PARK RD
# 4           CHECK WELL BEING              19B     50XX  N SHERIDAN RD
#
#                                      CPDUnitList  CFDUnitList  numerical  \
# 0                                    2211R 2213R          NaN      10300
# ...

# %%
df[['zipcodes']].iloc[0][0][0]
# Out:
# 60655

# %%
#https://stackoverflow.com/questions/23111990/pandas-dataframe-stored-list-as-string-how-to-convert-back-to-list
